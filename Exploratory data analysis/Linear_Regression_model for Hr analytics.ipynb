# %%
import numpy as np 
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('HR-Employee-Attrition.csv')

# %%
sns.barplot(y= df['MonthlyIncome'], x= df['YearsAtCompany'], color = 'blue')
# Out:
# <Axes: xlabel='YearsAtCompany', ylabel='MonthlyIncome'>

# %%
df['YearsAtCompany'].value_counts().sort_index()
# Out:
# YearsAtCompany
# 0      44
# 1     171
# 2     127
# 3     128
# 4     110
# 5     196
# 6      76
# 7      90
# 8      80
# 9      82
# 10    120
# 11     32
# 12     14
# 13     24
# 14     18
# 15     20
# 16     12
# 17      9
# 18     13
# 19     11
# 20     27
# 21     14
# 22     15
# 23      2
# 24      6
# 25      4
# 26      4
# 27      2
# 29      2
# 30      1
# 31      3
# 32      3
# 33      5
# 34      1
# 36      2
# 37      1
# 40      1
# Name: count, dtype: int64

# %%
sns.barplot(y= df['MonthlyIncome'], x= df['TotalWorkingYears'], color = 'blue')
# Out:
# <Axes: xlabel='TotalWorkingYears', ylabel='MonthlyIncome'>

# %%
x = df.iloc[:,[28,31]]

# %%
y = df.iloc[:,19]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# model = LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model = LinearRegression()

# %%
y_predict =model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score, mean_absolute_error

# %%
mse =mean_squared_error(Y_test,y_predict)

# %%
r2e = r2_score(Y_test,y_predict)

# %%
mse,r2e
# Out:
# (48464352.258331664, -0.008617157339654735)

# %%
mae = mean_absolute_error(Y_test,y_predict)

# %%
mae
# Out:
# 5975.0998255060185
