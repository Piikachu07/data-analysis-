# %%
import pandas as pd
from sklearn.ensemble import IsolationForest

# %%
df = pd.read_csv('creditcard_for_fraud_detection.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.shape
# Out:
# (284807, 31)

# %%
import matplotlib.pyplot as plt

# %%
for cols in range(1, 29):
    plt.scatter(x = df.iloc[:, cols], y = df.iloc[:, 29])
    plt.xlabel(f'Column {cols}')
    plt.ylabel('Column 29')
    plt.title(f'Scatter Plot of Column {cols} vs Column 29')
    plt.show()

# %%
clf = IsolationForest(contamination = 0.00172748)

# %%
clf.fit(df)
# Out:
# IsolationForest(contamination=0.00172748)

# %%
predict = clf.predict(df)

# %%
predict
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
import numpy as np
abd_index = np.where(predict<0)

# %%
len(abd_index)
# Out:
# 1

# %%
arr = [ 164,   1632,   2963,   4895,   5425,   6783,   6812,   6971,
          7617,   8296,   8335,   8610,   8615,   9035,   9179,   9252,
          9487,   9509,  10456,  10568,  10620,  10630,  10681,  10690,
         10783,  10801,  10891,  10897,  10906,  11343,  11710,  11841,
         11880,  12030,  12070,  12108,  12156,  12229,  12261,  12325,
         12369,  12468,  12922,  12938,  13394,  13405,  13499,  13617,
         13624,  13725,  13833,  13942,  14026,  14170,  14197,  14211,
         14900,  14920,  15166,  15204,  15225,  15364,  15451,  15476,
         15506,  15539,  15566,  15736,  15751,  15781,  15810,  15835,
         16110,  16780,  17317,  17366,  17407,  17453,  17480,  18633,
         18649,  19183,  19760,  20260,  21586,  22227,  22897,  22932,
         23026,  23128,  24633,  25387,  26686,  27749,  29667,  30398,
         30442,  30473,  31002,  31130,  31795,  31807,  32359,  33756,
         33949,  36889,  37000,  39769,  39973,  40695,  41667,  41943,
         42294,  42473,  42528,  42549,  42590,  42609,  42635,  42674,
         42696,  42700,  42741,  42756,  42769,  42784,  42856,  42887,
         42936,  42945,  42958,  43061,  43160,  43204,  43281,  43418,
         43428,  43432,  43681,  44091,  44223,  44254,  44270,  44513,
         46298,  46841,  47299,  47743,  48529,  48955,  49054,  49406,
         49776,  50287,  50735,  50922,  52524,  54018,  54696,  55829,
         56186,  56335,  57209,  57308,  58465,  59564,  61709,  61966,
         62413,  62868,  62946,  63421,  63634,  64329,  64411,  64460,
         65380,  65423,  66547,  67428,  68454,  68631,  68830,  68860,
         72407,  72761,  73784,  74185,  74243,  74403,  74429,  74699,
         76679,  76705,  76724,  76736,  77238,  77394,  77672,  77682,
         77814,  78106,  79103,  79267,  79296,  82400,  83213,  84397,
         85994,  86492,  90946,  91896,  93184,  94218,  97888,  98469,
         98675, 101249, 102441, 102442, 102443, 102444, 102445, 102446,
        104126, 104967, 105026, 105078, 106011, 108424, 110249, 110467,
        110608, 113094, 115192, 115273, 117639, 118764, 119630, 121787,
        123141, 125342, 129317, 130046, 131140, 131480, 131937, 138215,
        138706, 139217, 141257, 141258, 141259, 141260, 141500, 143333,
        143334, 144229, 144686, 145022, 145090, 145189, 145392, 145495,
        146117, 147008, 150561, 150601, 150644, 150647, 150654, 150660,
        150661, 150662, 150663, 150665, 150666, 150667, 150668, 150669,
        150677, 150678, 150679, 150680, 150684, 150687, 150692, 150697,
        150715, 150925, 151006, 151007, 151008, 151009, 151011, 151296,
        151462, 151519, 151807, 152223, 152295, 153241, 153823, 153835,
        153851, 154234, 154316, 154371, 154587, 154684, 154697, 154719,
        154720, 154979, 154986, 155296, 155299, 155741, 156374, 156861,
        157482, 158022, 158499, 158957, 163135, 163604, 164024, 164331,
        165400, 165582, 167289, 168402, 169140, 169457, 170007, 171814,
        173054, 173353, 173791, 175710, 176335, 176415, 176839, 177131,
        177168, 178208, 178583, 179589, 179846, 181964, 182698, 183273,
        184433, 184502, 185219, 185929, 186714, 187276, 188560, 189024,
        189242, 190088, 190137, 191533, 193068, 193887, 195218, 195718,
        196094, 196288, 197735, 198375, 199538, 199710, 199847, 201291,
        201638, 201775, 201869, 203489, 206228, 206255, 206783, 207958,
        208305, 209292, 210510, 210569, 211322, 211449, 211925, 212075,
        212822, 212950, 213160, 213188, 213261, 213675, 215571, 216065,
        217409, 217533, 217781, 218985, 219182, 219257, 219530, 219546,
        219640, 219776, 219889, 220090, 220212, 220437, 221219, 222351,
        222421, 222922, 224569, 224696, 226683, 226690, 226877, 227636,
        227921, 228158, 228525, 228723, 229036, 229859, 230073, 230293,
        230515, 230600, 230838, 230944, 230962, 231029, 231166, 231454,
        232014, 234519, 235319, 236429, 237019, 238412, 238966, 239532,
        240739, 240776, 240804, 241916, 242458, 242459, 242460, 242461,
        244674, 244693, 244698, 245273, 245474, 250924, 251138, 253712,
        256077, 256118, 260589, 261282, 261843, 262378, 262839, 262843,
        263178, 265157, 265657, 266105, 268364, 268880, 271762, 271773,
        271810, 271853, 271857, 271944, 273747, 274771, 279286, 279610,
        281066, 283268, 284249, 284795]

# %%
len(arr) # from here by applying isolation forest we can get 492 anomaly i.e outliers therefore we can say that for the given data set we can easily apply the Isolation forest
# Out:
# 492

# %%
x = df.values

# %%
abd_index = np.where(predict<0)
plt.scatter(df.iloc[:,1],df.iloc[:,29])
plt.scatter(x[abd_index,1],x[abd_index,29], edgecolors = 'red')

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)  
reduced_data = pca.fit_transform(df)

# %%
reduced_data = pd.DataFrame(reduced_data, columns = ['Column1','Column2'])

# %%
reduced_data.head()
# Out:
#         Column1     Column2  Outlier
# 0 -94813.862881   55.979467        0
# 1 -94813.854640  -90.953660        0
# 2 -94812.875662  285.024840        0
# 3 -94812.861396   29.859853        0
# 4 -94811.858408  -23.652028        0

# %%
reduced_data['Outlier'] = 0
reduced_data.loc[arr, 'Outlier'] = 1

# %%
plt.figure(figsize=(10, 6))
plt.scatter(reduced_data['Column1'],reduced_data['Column2'], c = df['Outlier'])
plt.title('Yellow balls represent the Outliers in the given data')
# Out:
# Text(0.5, 1.0, 'Yellow balls represent the Outliers in the given data')
